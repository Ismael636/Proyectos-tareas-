# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/Apuntes%20clase%2008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Archivos

#ejemplo.txt

file = open('ejemplo.txt','w')
file.write('Contenido a escribir')
file.close()

#‘r’: Por defecto, para leer el fichero.
#‘w’: Para escribir en el fichero.
#‘x’: Para la creación, fallando si ya existe.
#‘a’: Para añadir contenido a un fichero existente.
#‘b’: Para abrir en modo binario.

# %%
file = open('ejemplo.txt','r')
print(file.read())
# Out:
# Contenido a escribir

# %%
file = open('ejemplo.txt','r')
print(file.readline(6))
# Out:
# Conten

# %%
lista = ['manzana\n','pera\n','platano\n']
with open('ejemplo.txt','w') as file:
  file.writelines(lista)
  #este codigo modifica el archivo  y lo remplaza por el texto escrito
  #y lo guarda en forma de lista

# %%
with open('ejemplo.txt','r') as stop_words:
  lineas = [linea.strip() for linea in stop_words]

for linea in lineas:
  print(linea)

stop_words.close()
# Out:
# manzana
# pera
# platano
