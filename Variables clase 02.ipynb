# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/Variables%20clase%2002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tipos de variables
#al declarar variables, estas no pueden llevar un numero al comienzo, ni se pueden utilizar espacios o guiones

numero = 15
decimal = 0.35
texto = 'texto a escribir'
booleanos = True #En tipo booleano puede ir True o False


print(texto)
print(type(texto)) #el utilizar la funcion type es para mostrar que tipo de variable se esta utilizando
# Out:
# texto a escribir
# <class 'str'>

# %%
#variables
tupla =() #las variables de tuplas deben de llevar parentesis
lista =[] #las variables de lista, deben llevar corchetes
set_ ={} #se pone un guion bajo para no confundir la funcion set, debe de llevar llaves
diccionario ={2:2,1:5} #el diccionario se organiza por pares y usa llaves

# %%
#ejmplo variables

tupla=("hello",58)
lista=[1,2,3,4,56,78]
set_={1,2,3,4,78,974}
diccionario={2:5,6:8,0:1}

print(tupla)
print(lista)
print(set_)
print(diccionario)
# Out:
# ('hello', 58)
# [1, 2, 3, 4, 56, 78]
# {1, 2, 3, 4, 78, 974}
# {2: 5, 6: 8, 0: 1}
