# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/tarea%2006.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
matriz = [[2,4,6],[3,6,9],[10,20,30]]

for i in range(3):
  print(matriz[i])

print('\n')
numero = int(input('Ingresa numero por multiplicar con la lista: '))
print('\n')

for i in range(3):
  for j in range(3):
    matriz2[i][j] = numero*matriz[i][j]

for i in range(3):
  print(matriz2[i])
# Out:
# [2, 4, 6]
# [3, 6, 9]
# [10, 20, 30]
#
#
# Ingresa numero por multiplicar con la lista: 4
#
#
# [8, 16, 24]
# [12, 24, 36]
# [40, 80, 120]
