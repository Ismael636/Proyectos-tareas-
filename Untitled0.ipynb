# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("¿Cual es tu primer nombre?")
Nombre = input()
print("¿Cual es tu segundo nombre?")
Nombre2 = input()
print("¿Cual es tu primer apellido?")
Apellido = input()
print("¿Cual es tu segundo apellido?")
Apellido2 = input()

print("Mi nombre completo es:", Nombre, Nombre2, Apellido, Apellido2)
# Out:
# ¿Cual es tu primer nombre?
# Isma
# ¿Cual es tu segundo nombre?
# Alex
# ¿Cual es tu primer apellido?
# mendoza
# ¿Cual es tu segundo apellido?
# Morales
# Mi nombre completo es: Isma Alex mendoza Morales
