# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/Apuntes%2007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def funcion():
  print('Hola')
  a=2
  b=3
  c=a*b
  print(c)

# %%
funcion()
#funcion()
#funcion()
# Out:
# Hola
# 6

# %%
def funcion2(a):
  print('holo')
  b=3
  c=a*b
  print(c)

# %%
funcion2(5)
# Out:
# holo
# 15

# %%
def funcion3(a,b):
  #print('holo')
  c=a*b
  print(c)

# %%
funcion3(5,2)
# Out:
# 10

# %%
f=5
e=2
funcion3(f,e)
funcion3(f,1)
funcion3(8,5)
print('\n')
x=funcion3(f,e)
print(x)
print(type(x))
# Out:
# 10
# 5
# 40
#
#
# 10
# None
# <class 'NoneType'>

# %%
def funcion4(a,b):
  print(a*b)
  return a*b

# %%
mult=funcion4(f,e)
print(type(mult))
# Out:
# 10
# <class 'int'>

# %%
def func(a,b,d):
  c=a*b
  print(a*b)
  f='holaa'+d #variable de tipo string
  print(f)
  cs=str(c)
  lista=[1.4,2.7,3.5]
  return c, cs, lista

# %%
valores = func(f,e,' Uriel')
print(type(valores))
print(type(valores[0]))
print(type(valores[1]))
print(type(valores[2]))
# Out:
# 10
# holaa Uriel
# <class 'tuple'>
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %%
entero,string,lista =func(f,e,' Uriel')
if entero == valores[0]:
  print('son iguales')
# Out:
# 10
# holaa Uriel
# son iguales

# %%
def funci(a=2,b=3,d=' Suwie'):
  c=a*b
  print(a*b)
  f='holaa'+d #variable de tipo string
  print(f)
  cs=str(c)
  lista=[1.4,2.7,3.5]
  return c, cs, lista

# %%
prueba = funci(e,f,' suwawi')
# Out:
# 10
# holaa suwawi

# %%
def funcio(a=2,b=3,d=' Suwie'):
  c=a*b
  print(str(a)+ '*' +str(b) +' =',a*b)
  f='holaa'+d #variable de tipo string
  print(f)
  cs=str(c)
  lista=[1.4,2.7,3.5]
  return c, cs, lista

# %%
test = funcio(10,2,' orion')
# Out:
# 10*2 = 20
# holaa orion
