# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/Tarea%2003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Diccionario de automóviles
Autos=[
       {
           'placas':input('Introduce tu placa: '),
           'año':int(input('Introduce el año del auto: ')),
           'color':input('¿Que color es? '),
           'consumo':float(input('Litros del motor: '))
           
       },
       {
           'placas2':input('Introduce tu 2da placa: '),
           'año2':int(input('Introduce el año: ')),
           'color2':input('¿Que color es? '),
           'consumo2':float(input('Litros del motor: ')),
       }
]
DE1=input('Apartado extra 1er auto: ')
DE2=input('Informacion del apartado extra: ')
Autos.append({DE1:[DE2]})
DE3=input('Apartado extra 2do auto: ')
DE4=input('Informacion del apartado extra: ')
Autos.append({DE3:[DE4]})

print('\n1er Placa: ',Autos[0]['placas'])
print('El año es: ',Autos[0]['año'])
print('El color es: ',Autos[0]['color'])
print('Litros del motor: ',Autos[0]['consumo'])
print(DE1,': ',DE2)
print('-----------------------------------------------------')
print('\n2da Placa: ',Autos[1]['placas2'])
print('El año es: ',Autos[1]['año2'])
print('El color es: ',Autos[1]['color2'])
print('Litros del motor: ',Autos[1]['consumo2'])
print(DE3,': ',DE4)
Autos
# Out:
# Introduce tu placa: 36250
# Introduce el año del auto: 2019
# ¿Que color es? Blanco
# Litros del motor: 1
# Introduce tu 2da placa: 36251
# Introduce el año: 1992
# ¿Que color es? Rojo
# Litros del motor: 4.9
# Apartado extra 1er auto: Marca
# Informacion del apartado extra: Renault
# Apartado extra 2do auto: Modelo
# Informacion del apartado extra: F150
#
# 1er Placa:  36250
# El año es:  2019
# El color es:  Blanco
# Litros del motor:  1.0
# Marca :  Renault
# -----------------------------------------------------
#
# 2da Placa:  36251
# El año es:  1992
# El color es:  Rojo
# Litros del motor:  4.9
# Modelo :  F150
# [{'año': 2019, 'color': 'Blanco', 'consumo': 1.0, 'placas': '36250'},
#  {'año2': 1992, 'color2': 'Rojo', 'consumo2': 4.9, 'placas2': '36251'},
#  {'Marca': ['Renault']},
#  {'Modelo': ['F150']}]
