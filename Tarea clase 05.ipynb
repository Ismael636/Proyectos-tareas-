# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/Tarea%20clase%2005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Condicinales

carne='Doble triple'
salsa='De coral'
decorado='De lujo'
estilo='Animal'
guijarros='Extra'
vibracion='Exprimida'
eje='Con grasa lijera'
hazlo='Llorar'
quemalo='Si'
nadando='Si'
pepinillos='No'

if (carne == 'Doble triple' or
salsa=='De coral' or
decorado=='De lujo' or
estilo=='Animal' or
guijarros=='Extra' or 
vibracion=='Exprimida' or
eje=='Con grasa lijera' or
hazlo=='Llorar' or
quemalo=='Si' or
nadando=='Si' or
pepinillos=='Si'):
  print('Quiere la hamburguesa')
else:
  print('No quiere Hamburguesa')
# Out:
# Quiere la hamburguesa
