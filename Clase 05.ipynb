# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismael636/Proyectos-tareas-/blob/main/Clase%2005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Condicionales

if True:
  print('Hola')
else:
  print('Adios')
# Out:
# Hola

# %%
#Condicionales

if False:
  print('Hola')
else:
  print('Adios')
# Out:
# Adios

# %%
print('Bienvenido a clu pengüin')
print(' ')
edad=18
print('Tienes ' + str(edad) + ' años')

if edad<17:
  print('Necesitas permiso de tus padre')
else:
  print('Puedes crear la cuenta')
# Out:
# Bienvenido a clu pengüin
#
# Tienes 18 años
# Puedes crear la cuenta

# %%
#Condicionales

calificacion=9#int(input('Ingresa tu calificacion'))

if calificacion==7:
  print('Felicidades pero puedes mejorar')
elif calificacion==8:
  print('Felicidades estas mas cerca del 10')
elif calificacion==9:
  print('Felicidades, no es un 10 pero esta weno')
elif calificacion==10:
  print('Felicidades tienes 10')
else:
  print('Suerte la proxima')
# Out:
# Felicidades, no es un 10 pero esta weno

# %%
#Condicionales

camara = True
microfono = False

if camara == True and microfono == True:
    print('Puedes grabar')
else:
    print('No puedes grabar')
# Out:
# No puedes grabar

# %%
#Condicionales

camara = True
microfono = False

if camara == True or microfono == True:
    print('Puedes grabar')
else:
    print('No puedes grabar')
# Out:
# Puedes grabar

# %%
#Condicinales

carne='Doble triple'
salsa='De coral'
decorado='De lujo'
estilo='Animal'
guijarros='Extra'
vibracion='Exprimida'
eje='Con grasa lijera'
hazlo='Llorar'
quemalo='Si'
nadando='Si'
pepinillos='No'

if (carne == 'Doble triple' and
salsa=='De coral' and
decorado=='De lujo' and
estilo=='Animal' and
guijarros=='Extra' and 
vibracion=='Exprimida' and
eje=='Con grasa lijera' and
hazlo=='Llorar' and
quemalo=='Si' and
nadando=='Si' and
pepinillos=='Si'):
  print('Quiere la hamburguesa')
else:
  print('No quiere Hamburguesa')
# Out:
# Quiere la hamburguesa
